# %%
import squidpy as sq
import scanpy as sc
import scipy as scp
import numpy as np 
import pandas as pd
import scanorama as scan
from matplotlib.pyplot import rc_context
import liana as li

# %%
sc.logging.print_versions()
sc.set_figure_params(facecolor="white", figsize=(8, 8))
sc.settings.verbosity = 3
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# OpenGL                      3.1.7
# PIL                         9.4.0
# PyQt5                       NA
# annoy                       NA
# appdirs                     1.4.4
# appnope                     0.1.3
# arrow                       1.2.3
# asciitree                   NA
# asttokens                   NA
# attr                        22.2.0
# babel                       2.14.0
# backcall                    0.2.0
# cachey                      0.2.1
# certifi                     2022.12.07
# cffi                        1.15.1
# charset_normalizer          3.1.0
# cloudpickle                 3.0.0
# comm                        0.1.2
# cycler                      0.10.0
# cython_runtime              NA
# dask                        2024.2.1
# dask_image                  2023.08.1
# datashader                  0.16.0
# datatree                    0.0.14
# dateutil                    2.8.2
# ...

# %%
sclc = sc.read_h5ad('hlca/sclcSingletwGenes.h5ad')
sclc.uns['batch_condition']
# Out:
# array(['sample'], dtype=object)

# %%
sclc.obs.study
# Out:
# scrBT1428_CCACGGATCGCATGGC_lambrechts    Thienpont_2018
# BT1248_GGACAGGATGACCA_lambrechts         Thienpont_2018
# scrBT1428_TATGCCCTCCACTGGG_lambrechts    Thienpont_2018
# scrBT1426_ATTCTACTCTGTGCAA_lambrechts    Thienpont_2018
# scrBT1428_GGACGTCAGCTAACAA_lambrechts    Thienpont_2018
#                                               ...
# scrBT1428_AGACGTTTCTATCGCC_lambrechts    Thienpont_2018
# scrBT1427_CCCTCCTTCCCTTGTG_lambrechts    Thienpont_2018
# scrBT1428_AACTCCCTCAGATAAG_lambrechts    Thienpont_2018
# scrBT1428_GACTACACAGATTGCT_lambrechts    Thienpont_2018
# BT1247_GCCTCAACAGATCC_lambrechts         Thienpont_2018
# Name: study, Length: 20561, dtype: category
# Categories (1, object): ['Thienpont_2018']

# %%
# !pip install liana
# Out:
# Python(93651) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.7 MB/s eta 0:00:0000:01:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.2/204.2 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.4/114.4 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 8.7 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 11.1 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.0.0
#     Uninstalling platformdirs-3.0.0:
#       Successfully uninstalled platformdirs-3.0.0
# ...
#
# ...

# %%
import liana as li
sclc.raw.X
# ?rank_aggregate.__call__
# Out:
# Object `rank_aggregate.__call__` not found.

# %%
sc.pl.umap(sclc, color='cell_type', title='', size=20, frameon=False)
# Out:
# /Users/shivaramakrishna/Library/Python/3.9/lib/python/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
# /Users/shivaramakrishna/Library/Python/3.9/lib/python/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored

# %%
from liana.method import singlecellsignalr, connectome, cellphonedb, natmi, logfc, cellchat, geometric_mean
cellphonedb(sclc, groupby='cell_type', expr_prop=0.1, verbose=True, key_added='cpdb_res')
# Out:
# Using `.raw`!
# /Users/shivaramakrishna/Library/Python/3.9/lib/python/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# 32441 features of mat are empty, they will be removed.
# Make sure that normalized counts are passed!
# /Users/shivaramakrishna/Library/Python/3.9/lib/python/site-packages/liana/method/_pipe_utils/_pre.py:148: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
# /Users/shivaramakrishna/Library/Python/3.9/lib/python/site-packages/liana/method/_pipe_utils/_pre.py:151: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# The following cell identities were excluded: myofibroblast cell, multi-ciliated epithelial cell, epithelial cell of alveolus of lung
# ...

# %%
sclc.var
# Out:
#           feature_is_filtered original_gene_symbols feature_name  \
# A1BG                    False                  A1BG         A1BG
# A1BG-AS1                False              A1BG-AS1     A1BG-AS1
# A1CF                    False                  A1CF         A1CF
# A2M                     False                   A2M          A2M
# A2M-AS1                 False               A2M-AS1      A2M-AS1
# ...                       ...                   ...          ...
# RAB1B                   False                 RAB1B        RAB1B
# STC1                    False                  STC1         STC1
# STXBP1                  False                STXBP1       STXBP1
# TEC                     False                   TEC          TEC
# WFS1                    False                  WFS1         WFS1
#
#          feature_reference feature_biotype feature_length
# A1BG        NCBITaxon:9606            gene           3999
# A1BG-AS1    NCBITaxon:9606            gene           3374
# ...
